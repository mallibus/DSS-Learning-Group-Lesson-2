# %% [markdown]
# # Creating your own dataset from Google Images
#
# Original version from [Fast.ai Lesson 2](https://course.fast.ai/videos/?lesson=2)
#
# [Github repo](https://github.com/fastai/course-v3/blob/master/nbs/dl1/lesson2-download.ipynb)

# %% [markdown]
# ![Cover SLide](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide1.JPG)

# %% [markdown]
# # Plan of attack, what we are supposed to do

# %% [markdown]
# ![Agenda slide](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide2.JPG)

# %% [markdown]
# # What we will actually do

# %% [markdown]
# ![actual agenda slide](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide3.JPG)

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ads block add-ons (YouBlock) in Chrome. Otherwise window.open() coomand doesn't work. Then you can run the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide4.JPG)

# %% [markdown]
# For each search you will get a `download` file. You can remame it with you classes names to make things easy!
#
# in my case
# ```
# goldrake.txt
# daitarn3.txt
# jeeg.txt
# mazinga.txt
# tekkaman.txt
# icub.txt
# ```

# %% [markdown]
# ### Create directory into your server

# %%
path = Path('data/robots')

# create directory and all possibly missing parents, don't complain if already exists
path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Upload url files ito your server

# %% [markdown]
# Upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](https://raw.githubusercontent.com/fastai/course-v3/master/nbs/dl1/images/download_images/upload.png)

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
path.ls()
# Out:
# [WindowsPath('data/robots/daitarn3.txt'),
#  WindowsPath('data/robots/goldrake.txt'),
#  WindowsPath('data/robots/icub.txt'),
#  WindowsPath('data/robots/jeeg.txt'),
#  WindowsPath('data/robots/mazinga.txt'),
#  WindowsPath('data/robots/tekkaman.txt')]

# %% [markdown]
# ### Download images from files
#
# I get the classes right from the images files names

# %% [markdown]
# [pathlib documentation](https://docs.python.org/3/library/pathlib.html)
#
# `path.name`: A string representing the final path component, excluding the drive and root, if any
#
# `path.is_file`:Return `True` if the path points to a regular file (or a symbolic link pointing to a regular file), `False` if it points to another kind of file.
#
# `path.suffix`:The file extension of the final component, if any
#
# `path.stem`:The final path component, without its suffix

# %%
# get stem of all files with extension .txt
classes = [s.stem for s in path.ls() if s.suffix=='.txt']
classes
# Out:
# ['icub', 'jeeg', 'mazinga', 'tekkaman', 'goldrake', 'daitarn3']

# %%
for cls in classes:
    folder = cls
    file = f'{cls}.txt'
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)
    download_images(path/file, dest, max_pics=200)
    # If you have problems download, try with `max_workers=0` to see exceptions:
    #download_images(path/file, dest, max_pics=20, max_workers=0)

# occhio a sintassi f''
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
path.ls()
# Out:
# [WindowsPath('data/robots/daitarn3'),
#  WindowsPath('data/robots/daitarn3.txt'),
#  WindowsPath('data/robots/goldrake'),
#  WindowsPath('data/robots/goldrake.txt'),
#  WindowsPath('data/robots/icub'),
#  WindowsPath('data/robots/icub.txt'),
#  WindowsPath('data/robots/jeeg'),
#  WindowsPath('data/robots/jeeg.txt'),
#  WindowsPath('data/robots/mazinga'),
#  WindowsPath('data/robots/mazinga.txt'),
#  WindowsPath('data/robots/tekkaman'),
#  WindowsPath('data/robots/tekkaman.txt')]

# %%
classes
# Out:
# ['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman']

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# daitarn3
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='199' class='' max='199', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [199/199 00:05<00:00]
#     </div>
# goldrake
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
doc(verify_images)

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
doc(get_transforms)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman'], 6, 926, 231)

# %% [markdown]
# ## Train model

# %% [markdown]
# If you get this:
# ```
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-efdbe27853be> in <module>
# ----> 1 learn = cnn_learner(data, models.resnet34, metrics=error_rate)
#
# NameError: name 'cnn_learner' is not defined
# ```
# You have an old version of fastai library!
#
# [**1.0.47 (2019-03-06)**](https://github.com/fastai/fastai/blob/master/CHANGES.md#1047-2019-03-06)
#
# `create_cnn` becomes `cnn_learner`

# %%
import fastai; fastai.__version__
# Out:
# '1.0.53.post2'

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.834218</td>
#       <td>0.898860</td>
#       <td>0.316017</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.271680</td>
#       <td>0.659929</td>
#       <td>0.233766</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.979225</td>
#       <td>0.618557</td>
#       <td>0.216450</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.832028</td>
#       <td>0.608077</td>
#       <td>0.203463</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# https://docs.fast.ai/basic_train.html#Learner.unfreeze

# %%
learn.unfreeze()

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide24.jpg)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### Useful doc shortcuts

# %% [markdown]
# https://docs.fast.ai/basic_train.html#Discriminative-layer-training

# %% [markdown]
# https://docs.fast.ai/basic_train.html#Learner.lr_range

# %%
learn.fit_one_cycle(5, max_lr=slice(3e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.531884</td>
#       <td>0.530684</td>
#       <td>0.186147</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.405135</td>
#       <td>0.493072</td>
#       <td>0.160173</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.316891</td>
#       <td>0.413716</td>
#       <td>0.147186</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.252048</td>
#       <td>0.389021</td>
#       <td>0.116883</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.203635</td>
#       <td>0.371714</td>
#       <td>0.112554</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-4,5e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.090152</td>
#       <td>0.363645</td>
#       <td>0.108225</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.104517</td>
#       <td>0.383944</td>
#       <td>0.125541</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.105863</td>
#       <td>0.406116</td>
#       <td>0.116883</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.095649</td>
#       <td>0.337752</td>
#       <td>0.121212</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.083103</td>
#       <td>0.327642</td>
#       <td>0.121212</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .no_split()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/data_block.py:180: UserWarning: `no_split` is deprecated, please use `split_none`.
#   warn("`no_split` is deprecated, please use `split_none`.")

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .no_split()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)
learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, loosing all the results from cleaning the data from toplosses.

# %%
doc(ImageCleaner)

# %%
#If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
                    .no_split()
                    .label_from_df()
                    .transform(get_transforms(), size=224)
                    .databunch()
      )
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/data_block.py:180: UserWarning: `no_split` is deprecated, please use `split_none`.
#   warn("`no_split` is deprecated, please use `split_none`.")

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)
learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='18', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18/18 00:04<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %%
df = pd.read_csv(path/'cleaned.csv', header='infer')
df.sample(10)
# Out:
#                        name     label
# 698   daitarn3/00000049.jpg  daitarn3
# 346       icub/00000038.png      icub
# 170   goldrake/00000110.jpg  goldrake
# 354       icub/00000109.jpg      icub
# 36    goldrake/00000004.png  goldrake
# 761   tekkaman/00000182.jpg  tekkaman
# 408    mazinga/00000116.jpg   mazinga
# 1011      jeeg/00000176.jpg      jeeg
# 557   daitarn3/00000151.jpg  daitarn3
# 954       jeeg/00000187.png      jeeg

# %% [markdown]
# # Starting here  retraining after torch update

# %%
path
# Out:
# PosixPath('data/robots')

# %%
# If you already cleaned your data, run this cell instead of the one before
np.random.seed(42)
data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman'], 6, 870, 217)

# %% [markdown]
# Before cleaning output was
# `(['daitarn3', 'goldrake', 'icub', 'jeeg', 'mazinga', 'tekkaman'], 6, 926, 231)`

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# I'm running 6 epochs as in the first run I noticed that the loss was still going down after 4 epochs

# %%
learn.fit_one_cycle(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.928109</td>
#       <td>1.227626</td>
#       <td>0.465438</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.416983</td>
#       <td>0.619274</td>
#       <td>0.258065</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.096943</td>
#       <td>0.533943</td>
#       <td>0.225806</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.900081</td>
#       <td>0.520981</td>
#       <td>0.216590</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.757896</td>
#       <td>0.501093</td>
#       <td>0.193548</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-cleaned')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-4,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.472044</td>
#       <td>0.395994</td>
#       <td>0.152074</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.369325</td>
#       <td>0.590679</td>
#       <td>0.202765</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.294562</td>
#       <td>0.480802</td>
#       <td>0.119816</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.225447</td>
#       <td>0.373075</td>
#       <td>0.105991</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.175542</td>
#       <td>0.348052</td>
#       <td>0.087558</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-cleaned')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, max_lr=slice(2e-4,4e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.043884</td>
#       <td>0.354934</td>
#       <td>0.092166</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.046303</td>
#       <td>0.394988</td>
#       <td>0.105991</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.048094</td>
#       <td>0.409648</td>
#       <td>0.105991</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.044827</td>
#       <td>0.371028</td>
#       <td>0.096774</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.038617</td>
#       <td>0.345803</td>
#       <td>0.082949</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-cleaned')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# Check default device before changing it
defaults.device
# Out:
# device(type='cuda', index=0)

# %%
# Double check I can put it back to cuda :-)
defaults.device == torch.device('cuda',index=0)
# Out:
# True

# %%
# And finally set it to CPU
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'mazinga'/'00000190.jpg')
img
# Out:
# Image (3, 361, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category mazinga

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# # Put into production with Render
#
# Instructions are here https://course.fast.ai/deployment_render.html#one-time-setup
#
# In a nutshell:
#
# - Fork https://github.com/render-examples/fastai-v3 repo in your github
# - Create a Render account, better if you do it using your Github account
# - Get a direct link to your model file
# - Edit server.py and index.html

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide25.jpg)

# %% [markdown]
# ## How to get direct link to a model file
#
# - Download `export.pkl` file from  `data/robots` folder
# - Put it into a cloud service such as Google Drive ir Dropbox
# - Get a sharable link to the .pkl file
# - Generate direct link with a service like  https://syncwithtech.blogspot.com/p/direct-download-link-generator.html

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide8.JPG)

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide9.JPG)

# %% [markdown]
# https://syncwithtech.blogspot.com/p/direct-download-link-generator.html

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide10.JPG)

# %% [markdown]
# ## It may not work first time:

# %% [markdown]
# ![downlaod images](https://raw.githubusercontent.com/mallibus/DSS-Learning-Group-Lesson-2/master/img/Slide14.JPG)

# %% [markdown]
# ## Things that can go wrong (in the CNN performance)

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
# overfitting
# concetti diverso di overfitting: 
    # - mischiare rumore a segnale (per questo accuracy train migliore di accuracy valid)
    # - trainare (fit) oltre il punto di best accuracy valid

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# ...

# %% [markdown]
# ## But also...

# %%
learn.recorder.plot_losses()

# %% [markdown]
# **Question:** When generating new image dataset, how do you know how many images are enough? What are ways to measure "enough"? [1:08:35](https://www.youtube.com/watch?v=Egp4Zajhzog&feature=youtu.be&t=4115)
#
# Great question. Another possible problem you have is you don't have enough data. How do you know if you don't have enough data? Because you found a good learning rate (i.e. if you make it higher than it goes off into massive losses; if you make it lower, it goes really slowly) and then you train for such a long time that your error starts getting worse. So you know that you trained for long enough. And you're still not happy with the accuracy﹣it's not good enough for the teddy bear cuddling level of safety you want. So if that happens, there's a number of things you can do and we'll learn pretty much all of them during this course but one of the easiest one is get more data. If you get more data, then you can train for longer, get a higher accuracy, lower error rate, without overfitting.
#
# Unfortunately there is no shortcut. I wish there was. I wish there's some way to know ahead of time how much data you need. But I will say this﹣most of the time, you need less data than you think. So organizations very commonly spend too much time gathering data, getting more data than it turned out they actually needed. So get a small amount first and see how you go.

# %% [markdown]
# ## ... and this is what we do in lesson2-download-MM-2
